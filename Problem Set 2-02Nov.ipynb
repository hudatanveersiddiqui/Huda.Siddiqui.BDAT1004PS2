# %% [markdown]
# # Question 1
# ![image.png](attachment:image.png)

# %% [markdown]
# ---Displayed value will be 6\
# Every time function b() is called, the global variable a is updated to\
# a = a + 2

# %% [markdown]
# # Question 2
# ![image.png](attachment:image.png)

# %%
def file_length(file_name):
    try:
        file = open(file_name)
        contents = file.read()
        file.close()
        print(len(contents))
    except:
        print('File %s not found' % file_name)

# %% [markdown]
# # Question 3
# Write a class named Marsupial that can be used as shown below:\
# \>>> m = Marsupial()\
# \>>> m.put_in_pouch('doll')
# \
# \>>> m.put_in_pouch('firetruck')
# \
# \>>> m.put_in_pouch('kitten')
# \
# \>>> m.pouch_contents() \['doll', 'firetruck', 'kitten'\]\
# \
# Now write a class named Kangaroo as a subclass of Marsupial that inherits all the attributes of Marsupial and also:\
# a. extends the Marsupial \__init__ constructor to take, as input, the coordinates x and y of the Kangaroo object,\
# \
# b. supports method jump that takes number values dx and dy as input and moves the kangaroo by dx units along the x-axis and by dy units along the y-axis, and\
# \
# c. overloads the \__str__ operator so it behaves as shown below.\
# \
# \>>> k = Kangaroo(0,0)
# \
# \>>> print(k) I am a Kangaroo located at coordinates (0,0)
# \
# \>>> k.put_in_pouch('doll')
# \
# \>>> k.put_in_pouch('firetruck')
# \
# \>>> k.put_in_pouch('kitten')
# \
# \>>> k.pouch_contents() \['doll', 'firetruck', 'kitten'\]
# \>>> k.jump(1,0)
# \
# \>>> k.jump(1,0)
# \
# \>>> k.jump(1,0)
# \
# \>>> print(k)\
# I am a Kangaroo located at coordinates (3,0)

# %%
class Marsupial:

    def __init__(self):
        self.items = []

    def put_in_pouch(self, item):
        self.items.append(item)

    def pouch_contents(self):
        print(self.items)


class Kangaroo(Marsupial):

    def __init__(self, x, y):
        super(Kangaroo, self).__init__()
        self.x = x
        self.y = y

    def jump(self, dx, dy):
        self.x = self.x + dx
        self.y = self.y + dy

    def __str__(self):
        return 'I am a Kangaroo located at coordinates (%d,%d)' % (self.x, self.y)

# %% [markdown]
# # Question 4
# Write function collatz() that takes a positive integer x as input and prints the Collatz sequence starting at x. A Collatz sequence is obtained by repeatedly applying this rule to the previous number x in the sequence:\
# \
# x = {𝑥/2 𝑖𝑓 𝑥 𝑖𝑠 𝑒𝑣𝑒𝑛\
# 3𝑥+1 𝑖𝑓 𝑥 𝑖𝑠 𝑜𝑑𝑑\
# \
# Your function should stop when the sequence gets to number 1. Your implementation must be recursive, without any loops.\
# \
# \>>> collatz(1)\
# 1\
# \>>> collatz(10)\
# 10\
# 5\
# 16\
# 8\
# 4\
# 2\
# 1

# %%
def collatz(x):
    print(x)
    if(x == 1):
        return
    elif(x % 2 == 0):
        collatz(x / 2)
    else:
        collatz(3*x + 1)

# %% [markdown]
# # Question 5
# ![image.png](attachment:image.png)

# %%
def binary(decimal):
    if(decimal > 0):
        binary((int)(decimal/2))
        print(decimal % 2, end='')

# %% [markdown]
# # Question 6
# Implement a class named HeadingParser that can be used to parse an HTML document, and retrieve and print all the headings in the document. You should implement your class as a subclass of HTMLParser, defined in Standard Library module html.parser. When fed a string containing HTML code, your class should print the headings, one per line and in the order in which they appear in the document. Each heading should be indented as follows: an h1 heading should have indentation 0, and h2 heading should have indentation 1, etc. Test your implementation using w3c.html.
# \
# \>>> infile = open('w3c.html')
# \
# \>>> content = infile.read()
# \
# \>>> infile.close()
# \
# \>>> hp = HeadingParser()
# \
# \>>> hp.feed(content)
# \
# W3C Mission\
# Principles

# %% [markdown]
# # Question 7
# ![image.png](attachment:image.png)

# %% [markdown]
# # Question 8
# Write SQL queries on the below database table that return:\
# a) All the temperature data.\
# b) All the cities, but without repetition.\
# c) All the records for India.\
# d) All the Fall records.\
# e) The city, country, and season for which the average rainfall is between 200 and 400 millimeters.\
# f) The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order.\
# g) The total annual rainfall for Cairo.\
# h) The total rainfall for each season.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Assuming table name to be TemperatureTable, Temperature (C) Column renamed to TemperatureC and Rainfall (mm) renamed to RainfallMM\
# \
# a-  All the temperature data.\
#     SELECT\
#     TemperatureC\
#     FROM\
#     TemperatureTable\
#     \
# b-  All the cities, but without repetition.\
#     SELECT\
#     City\
#     FROM\
#     TemperatureTable\
#     \
#     GROUP BY\
#     City\
#     \
# c- All the records for India.\
#     SELECT *\
#     FROM\
#     TemperatureTable\
#     \
#     WHERE\
#     Country='India'\
#     \
# d-  All the Fall records.\
#     SELECT *
#     FROM\
#     TemperatureTable\
#     \
#     WHERE\
#     Season='Fall'\
#     \
# e-  The city, country, and season for which the average rainfall is between 200 and 400 millimeters.\
#     SELECT\
#     City,\
#     Country,\
#     Season,\
#     RainfallM\
#     FROM\
#     TemperatureTable\
#     \
#     WHERE\
#     (Rainfall>='200'\
#     AND\
#     Rainfall<='400')\
# \
# f- The city and country for which the average Fall temperature is above 20 degrees, in increasing temperature order.
#     \
#     SELECT\
#     City,\
#     Country,\
#     TemperatureC\
#     \
#     From\
#     TemperatureTable\
#     Where\
#     TemperatureC>'20'\
#     \
#     Order By\
#     TemperatureC ASC\
#     \
# g- The total annual rainfall for Cairo
# \
#     SELECT\
#     Country,\
#     Sum(RainfallMM)\
# \
#     FROM\
#     TemperatureTable
# \
#     WHERE\
#     Country='Cairo'\
# \
#     GROUP BY\
#     Country\
# \
# h) The total rainfall for each season\
# \
#     SELECT\
#     Season,\
#     SUM(RainfallMM)\
# \
#     FROM TemperatureTable\
#     \
#     GROUP BY\
#     Season

# %% [markdown]
#  # Question 9
#  ![image.png](attachment:image.png)
#  \
#  \
#  References for Question 9: \
#  https://www.codegrepper.com/search.php?q=list%20comprehension \
#  https://www.learnpython.dev/03-intermediate-python/20-advanced-looping/10-list-comprehensions/ \
#  \
#  Note: all work done without any copy paste from google but references are enclosed to understand difference between List Comprehension and how to apply conditional list comprehension expression.

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
my_upperlist =[word.upper() for word in words]
print(my_upperlist)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
my_lowerlist =[word.lower() for word in words]
print(my_upperlist)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
my_list_length =[len(word) for word in words]
print(my_list_length)
# Out:
# [3, 5, 5, 3, 5, 4, 3, 4, 3]

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
my_list = [[word.upper(),word.lower(),len(word)] for word in words]
print(my_list)
# Out:
# [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
my_list = [word for word in words if len(word) >=4]
print(my_list)
# Out:
# ['quick', 'brown', 'jumps', 'over', 'lazy']

# %% [markdown]
# ___________________________________________________________________________________________
# # THE END
